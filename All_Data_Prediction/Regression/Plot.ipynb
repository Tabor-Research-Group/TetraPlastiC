# %%
import pandas as pd
from sklearn import svm
import numpy as np
import re
import random
import matplotlib.pyplot as plt
import pickle
from sklearn.metrics import mean_squared_error, r2_score

plt.rcParams['figure.dpi'] = 300

# Function to convert a string expression into a pandas Series operation
def string_to_pandas_series_ops(string, variable):
    for variable_name, series in variable.items():
        exec(f"{variable_name} = series")
    return eval(re.sub(r"[a-zA-Z]+\d+", lambda match: f"{match.group()} ", string))

def replace_features(match):
    feature = match.group(0)
    return index_series.get(feature, feature)

def r_squared(y, y_pred):
    y_bar = np.mean(y)
    ss_tot = np.sum((y-y_bar)**2)
    ss_res = np.sum((y-y_pred)**2)
    return 1 - (ss_res/ss_tot)

def MAD(y, y_pred):
    return np.mean(np.abs(y-y_pred))/np.mean(np.abs(y))



Feature1, Feature2 = [], []
Selected_feature_space = []
# Loop over 100 datasets
for i in range(100):
    tmp3 = []
    tmp3_feature1, tmp3_feature2 = [], []
    for l in range(7):
        # Load training and testing data
        df_train = pd.read_csv(f'Ttr/{i}/{l}/train.dat', sep='\t')
        df_test = pd.read_csv(f'Ttr/{i}/{l}/test.dat', sep='\t')
        H_train, H_test = df_train['Properties'], df_test['Properties']

        # Extract feature names
        variable_names = [f"feature{j}" for j in range(1, df_train.shape[1] - 1)]
        variable_ref = {name: df_train[name] for name in variable_names}
        variable_test = {name: df_test[name] for name in variable_names}

        # Read model and feature space files
        with open(f'Ttr/{i}/{l}/Models/top0100_D002', 'r') as model_file, \
             open(f'Ttr/{i}/{l}/SIS_subspaces/Uspace.expressions', 'r') as feature_space, \
             open(f'./feature_name_{i}_{l}', "rb") as fp:
            lines_model = model_file.readlines()
            lines_feature = feature_space.readlines()
            feature_name = pickle.load(fp)
                 
        tmp2 = []
        # Loop over 100 models
        tmp2_feature1, tmp2_feature2 = [], []
        for j in range(100):
            ID1, ID2 = map(int, [lines_model[j+1].split()[4], lines_model[j+1].split()[5].replace(')', '')])
            Feature1_string, Feature2_string = lines_feature[ID1-1].split()[0], lines_feature[ID2-1].split()[0]
            feature1 = string_to_pandas_series_ops(Feature1_string, variable_ref)
            feature2 = string_to_pandas_series_ops(Feature2_string, variable_ref)

            index_series = pd.Series(feature_name, index=[f'feature{i+1}' for i in range(len(feature_name))])
            output_string = re.sub(r'feature\d+', replace_features, Feature1_string)
            tmp2_feature1.append(output_string)
            output_string = re.sub(r'feature\d+', replace_features, Feature2_string)
            tmp2_feature2.append(output_string)
        
            # Extract feature indices
            tmp = [feature_name[int(k)-1] for k in re.findall(r'feature(\d+)', Feature1_string)]
            tmp += [feature_name[int(k)-1] for k in re.findall(r'feature(\d+)', Feature2_string)]
            tmp2.append(tmp)
        tmp3.append(tmp2)
        tmp3_feature1.append(tmp2_feature1)
        tmp3_feature2.append(tmp2_feature2)
    Feature1.append(tmp3_feature1)
    Feature2.append(tmp3_feature2)
    Selected_feature_space.append(tmp3)

# Identify frequently selected features
selected_feature, feature_counts = np.unique([q for x in Selected_feature_space for y in x for z in y for q in z], return_counts=True)
selected_index = np.where(feature_counts / sum(feature_counts) > 0.01)[0]

# # Plot feature selection ratio
# plt.bar(selected_feature[selected_index], feature_counts[selected_index] / sum(feature_counts))
# plt.xticks(rotation='vertical')
# plt.xlabel('Features')
# plt.ylabel('Ratio in the SISSO Model Ensemble')
# plt.title('Selected Feature Ratio from Enthalpy Prediction')

# %%
# Load test scores
all_Y_test = np.load('all_model_Y_test_Ttr.npy')
all_Y_train = np.load('all_model_Y_train_Ttr.npy')

all_test_score = []
for i in range(all_Y_test.shape[0]):
    tmp2 = []
    for j in range(all_Y_test.shape[1]):
        tmp = []
        for k in range(all_Y_test.shape[2]):
            tmp.append(r_squared(all_Y_test[i,j,k,0,:],all_Y_test[i,j,k,1,:]))
        tmp2.append(tmp)
    all_test_score.append(tmp2)
all_test_score = np.array(all_test_score)

# %%
plt.scatter(all_Y_test[84][1][37][0],all_Y_test[84][1][37][1],c = '#2a9d8f')
plt.plot([0,72],[0,72],linestyle='dashed',c='#f4a261')
plt.xlabel('Actual (kcal/mol)',fontsize=18)
plt.ylabel('Predicted (kcal/mol)',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Entropy Prediction (Good Performance)')
plt.show()

# %%
plt.scatter(all_Y_test[0][0][0][0],all_Y_test[0][0][0][1],c = '#2a9d8f')
plt.plot([0,45],[0,45],linestyle='dashed',c='#f4a261')
plt.xlabel('Actual (cal/mol/K)',fontsize=18)
plt.ylabel('Predicted (cal/mol/K)',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Enthalpy Prediction (Poor Performance)')
plt.show()

# %%
# Entropy

print(MAD(all_Y_test[84][1][37][0],all_Y_test[84][1][37][1]))
print(r_squared(all_Y_test[84][1][37][0],all_Y_test[84][1][37][1]))
print(MAD(all_Y_test[0][0][0][0],all_Y_test[0][0][0][1]))
print(r_squared(all_Y_test[0][0][0][0],all_Y_test[0][0][0][1]))

# %%
# Enthalpy
print(MAD(all_Y_test[0][1][39][0],all_Y_test[0][1][39][1]))
print(r_squared(all_Y_test[0][1][39][0],all_Y_test[0][1][39][1]))
print(MAD(all_Y_test[0][0][0][0],all_Y_test[0][0][0][1]))
print(r_squared(all_Y_test[0][0][0][0],all_Y_test[0][0][0][1]))
# Out:
# 0.09044036955915521
# 0.9076650706602504

# %%
# Out:
# 0.501715293945005
# -0.0884002377872064

# %%
selected_feature_modified = np.array([r'$\sigma_{ang}$', '$\it{Br}$', '$\it{C_4H_9}$', '$\it{CH_2Cl}$', '$\it{CH_2F}$', '$\it{CH_2NH_2}$',
       '$\it{CHClOH}$', '$\it{CHFOH}$', '$\it{CHO}$', '$\it{COCl}$', '$\it{COOH}$', 'Center of Mass', '$\it{Cl}$',
       '$E_{CT}$', '$E_{dispersion}$', '$\it{F}$',
       'Interaction Energy', 'Maxacc', '$\it{NH_2}$', '$\it{NO_2}$', '$\mu_R$',
       '$\sigma_R$', '$\it{SH}$', 'Symmetry', 'Volume', '$\mu_{dist}$',
       '$\sigma_{acc}$'])

# %%
selected_feature
# Out:
# array(['ANGSDEV', 'Br', 'C4H9', 'CH2Cl', 'CH2F', 'CH2NH2', 'CHClOH',
#        'CHFOH', 'CHO', 'COCl', 'COOH', 'Center of Mass', 'Cl',
#        'E_CT(kJ/mol)', 'E_dispersion(kJ/mol)', 'F', 'H',
#        'Interaction Energy(kJ/mol)', 'Maxacc', 'NH2', 'NO2', 'Ravg',
#        'Rstdev', 'SH', 'Volume(bohr**3/mol)', 'distavg', 'stdevacc'],
#       dtype='<U26')

# %%
# Load test scores
all_score_feature = [all_test_score[i][j][k] for i in range(len(Selected_feature_space)) for j in range(len(Selected_feature_space[i])) for k in range(len(Selected_feature_space[i][j])) for l in Selected_feature_space[i][j][k]]

score_stacking = []
for i in selected_feature:
    tmp = np.zeros(6)
    tmp_indices = np.where(np.array([l for y in Selected_feature_space for x in y for z in x for l in z]) == i)[0]
    all_scores = np.array(all_score_feature)[tmp_indices]
    for j in all_scores:
        if j >=0.8:
            tmp[5] += 1
        elif j >= 0.6 and j < 0.8:
            tmp[4] += 1
        elif j >= 0.4 and j < 0.6:
            tmp[3] += 1
        elif j >= 0.2 and j < 0.4:
            tmp[2] += 1
        elif j >= 0 and j < 0.2:
            tmp[1] += 1
        else:
            tmp[0] += 1
    score_stacking.append(tmp)

all_number = sum(sum(score_stacking))

# %%
fig, ax = plt.subplots()
labels = ['$R^2$ < 0.0', '0.0 <= $R^2$ < 0.2', '0.2 <= $R^2$ < 0.4','0.4 <= $R^2$ < 0.6',
                                   '0.6 <= $R^2$ < 0.8','0.8 <= $R^2$ < 1.0']
width = 0.5
color_codes = ['#264653', '#2a9d8f', '#8ab17d', '#e9c46a', '#f4a261','#8c510a']
for i in range(6):
    bottom = np.sum(np.array(score_stacking)[:,:i],axis=1)/all_number
    ax.bar(selected_feature_modified, np.array(score_stacking)[:,i]/all_number,width, label=labels[i], bottom=bottom,color=color_codes[i])

plt.xticks(rotation='vertical')
plt.xlabel('Descriptors')
plt.ylabel('Ratio in the SISSO Model Ensemble')
# ax.legend()
plt.title('Selected Descriptors Ratio from Transition Temperature Prediction')
plt.legend()

# %%
# Load test scores
all_Y_test = np.load('all_model_Y_test_H.npy')
all_Y_train = np.load('all_model_Y_train_H.npy')

all_test_score = []
for i in range(all_Y_test.shape[0]):
    tmp2 = []
    for j in range(all_Y_test.shape[1]):
        for k in range(all_Y_test.shape[2]):
            tmp2.append(r_squared(all_Y_test[i,j,k,0,:],all_Y_test[i,j,k,1,:]))
    all_test_score.append(tmp2)
all_test_score = np.array(all_test_score)
# all_test_score = all_test_score.flatten()

# %%
weights = np.ones_like(all_test_score[5])/float(len(all_test_score[5]))
plt.hist(all_test_score[5], weights = weights,bins=50,color = '#264653',rwidth=0.75)
plt.xlim(-1.8,1.0)
plt.ylim(0.0,0.10)
plt.xlabel('$R^2$', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Ratio',fontsize=20)
plt.title('Enthalpy Prediction Performance',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Enthalpy Prediction Performance')

# %%
weights = np.ones_like(all_test_score)/float(len(all_test_score))
plt.hist(all_test_score, weights = weights,bins=1000,color = '#264653',rwidth=0.75)
plt.xlim(-1.8,1.0)
plt.ylim(0.0,0.10)
plt.xlabel('$R^2$', fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('Ratio',fontsize=20)
plt.title('Enthalpy Prediction Performance',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Enthalpy Prediction Performance')
